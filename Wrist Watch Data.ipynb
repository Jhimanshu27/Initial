# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_excel('Watch_Data.xlsx')

# %%
df
# Out:
#            Brand        Movement Case material Bracelet material  \
# 0         Roamer       Automatic         Steel             Steel
# 1         Czapek       Automatic         Steel             Steel
# 2      Montblanc          Quartz         Steel             Steel
# 3           Cyma  Manual winding         Steel             Steel
# 4         Sector       Automatic         Steel             Steel
# ...          ...             ...           ...               ...
# 43725        ZRC       Automatic         Steel             Steel
# 43726        ZRC          Quartz         Steel             Steel
# 43727        ZRC          Quartz         Steel             Steel
# 43728        ZRC       Automatic         Steel            Rubber
# 43729        ZRC       Automatic         Steel             Steel
#
#       Year of production          Condition  \
# 0                 Mystry  Like new & unworn
# 1                   2024  Like new & unworn
# 2                 Mystry                New
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43730 entries, 0 to 43729
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Brand                         43730 non-null  object
#  1   Movement                      43730 non-null  object
#  2   Case material                 43730 non-null  object
#  3   Bracelet material             43730 non-null  object
#  4   Year of production            43730 non-null  object
#  5   Condition                     43730 non-null  object
#  6   Scope of delivery             43730 non-null  object
#  7   Gender                        43730 non-null  object
#  8   Price                         43730 non-null  int64
#  9   Availability                  43730 non-null  object
#  10  Shape                         43730 non-null  object
#  11  Water resistance              43730 non-null  int64
# ...

# %%
df.describe()
# Out:
#               Price  Water resistance  Watches Sold by the Seller  \
# count  4.373000e+04      43730.000000                43730.000000
# mean   9.909723e+03          6.339790                 1461.420421
# std    5.681002e+04         13.180351                 3418.499995
# min    5.000000e+01          0.000000                    0.000000
# 25%    5.530000e+02          0.000000                    9.000000
# 50%    1.699000e+03          0.000000                  327.000000
# 75%    5.157000e+03         10.000000                 1182.000000
# max    5.999995e+06        120.000000                19515.000000
#
#        Active listing of the seller  Seller Reviews  Revenue in Millions
# count                  43730.000000    43730.000000         43730.000000
# mean                     923.372582      938.046193             5.760875
# std                     1927.418664     2088.128606            29.361988
# min                        0.000000        0.000000             0.000000
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Movement', 'Case material', 'Bracelet material',
#        'Year of production', 'Condition', 'Scope of delivery', 'Gender',
#        'Price', 'Availability', 'Shape', 'Water resistance', 'Crystal', 'Dial',
#        'Bracelet color', 'Clasp', 'Watches Sold by the Seller',
#        'Active listing of the seller', 'Fast Shipper', 'Trusted Seller',
#        'Punctuality', 'Seller Reviews'],
#       dtype='object')

# %%
df['Trusted Seller']= df['Trusted Seller'].astype(bool)
df['Punctuality']= df['Punctuality'].astype(bool)

# %%
df
# Out:
#            Brand        Movement Case material Bracelet material  \
# 0         Roamer       Automatic         Steel             Steel
# 1         Czapek       Automatic         Steel             Steel
# 2      Montblanc          Quartz         Steel             Steel
# 3           Cyma  Manual winding         Steel             Steel
# 4         Sector       Automatic         Steel             Steel
# ...          ...             ...           ...               ...
# 43725        ZRC       Automatic         Steel             Steel
# 43726        ZRC          Quartz         Steel             Steel
# 43727        ZRC          Quartz         Steel             Steel
# 43728        ZRC       Automatic         Steel            Rubber
# 43729        ZRC       Automatic         Steel             Steel
#
#       Year of production          Condition  \
# 0                 Mystry  Like new & unworn
# 1                   2024  Like new & unworn
# 2                 Mystry                New
# ...

# %%
Luxury_watches = df[df['Price']>=20000]

# %%
Luxury_watches
# Out:
#                     Brand        Movement Case material Bracelet material  \
# 1                  Czapek       Automatic         Steel             Steel
# 8                  Czapek       Automatic         Steel            Rubber
# 60                Bulgari  Manual winding   Yellow gold       Yellow gold
# 68                HermÃ¨s          Quartz   Yellow gold       Yellow gold
# 72                   Ebel  Manual winding      Platinum          Platinum
# ...                   ...             ...           ...               ...
# 43479  Van Cleef & Arpels       Automatic    White gold        White gold
# 43480  Van Cleef & Arpels          Quartz         Steel             Steel
# 43560      Vianney Halter       Automatic   Yellow gold       Yellow gold
# 43594             Vulcain       Automatic         Steel           Leather
# 43654              Zenith       Automatic     Rose gold         Rose gold
#
#       Year of production          Condition  \
# ...

# %%
brand_sales = df.groupby('Brand')['Price'].sum().sort_values(ascending = False).reset_index()

# %%
Top_10_Most_Valued_Watches = brand_sales.head(10)

# %%
Top_10_Most_Valued_Watches['Price'] = Top_10_Most_Valued_Watches ['Price']/1_000_000
# Out:
# C:\Users\JHimanshu27\AppData\Local\Temp\ipykernel_15804\1837143699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top_10_Most_Valued_Watches['Price'] = Top_10_Most_Valued_Watches ['Price']/1_000_000

# %%
Top_10_Most_Valued_Watches = Top_10_Most_Valued_Watches.rename(columns={'Brand':'Brand_Name','Price':'Price_in_Millions'})
Top_10_Most_Valued_Watches
# Out:
#           Brand_Name  Price_in_Millions
# 0      Richard Mille          67.603648
# 1     Patek Philippe          48.066850
# 2    Audemars Piguet          20.273885
# 3         F.P.Journe          19.197948
# 4  A. Lange & SÃ¶hne          14.261817
# 5         De Bethune          12.556823
# 6       Roger Dubuis          10.076868
# 7        Jacob & Co.           8.336621
# 8               Mb&f           8.311119
# 9              Bovet           7.122747

# %%
Top_10_Most_Valued_Watched['Price_in_Millions'] = np.ceil(Top_10_Most_Valued_Watched['Price_in_Millions'])
Top_10_Most_Valued_Watched
plt.figure(figsize= (20,4))
sns.barplot(x = 'Brand_Name', y = 'Price_in_Millions' , data = Top_10_Most_Valued_Watched, color = 'Red')
# Out:
# <Axes: xlabel='Brand_Name', ylabel='Price_in_Millions'>

# %%
plt.figure(figsize = (5,5), facecolor = 'Pink')
ax = sns.boxplot (Top_10_Most_Valued_Watched['Price_in_Millions'],width = 0.8, color = 'Blue')

# %%
Categorical_data= df[['Brand', 'Movement', 'Case material', 'Bracelet material','Year of production', 'Trusted Seller','Condition', 'Scope of delivery', 'Gender','Availability', 'Shape','Crystal', 'Dial','Bracelet color', 'Clasp']]

# %%
df['Price'].describe()
# Out:
# count    4.373000e+04
# mean     9.909723e+03
# std      5.681002e+04
# min      5.000000e+01
# 25%      5.530000e+02
# 50%      1.699000e+03
# 75%      5.157000e+03
# max      5.999995e+06
# Name: Price, dtype: float64

# %%
Categorical_data.dtypes
# Out:
# Brand                 object
# Movement              object
# Case material         object
# Bracelet material     object
# Year of production    object
# Trusted Seller         int64
# Condition             object
# Scope of delivery     object
# Gender                object
# Availability          object
# Shape                 object
# Crystal               object
# Dial                  object
# Bracelet color        object
# Clasp                 object
# dtype: object

# %%
Numerical_data = df.drop(Categorical_data, axis = 1)

# %%
Numerical_data.dtypes
# Out:
# Price                           int64
# Water resistance                int64
# Watches Sold by the Seller      int64
# Active listing of the seller    int64
# Fast Shipper                    int64
# Punctuality                     int64
# Seller Reviews                  int64
# dtype: object

# %%
# Comparision of Punctuality bifurcated by Most Priced Bracelet color  
plt.figure(figsize= (30,8))
sns.barplot(x = 'Bracelet color', y = 'Price' , data = df ,hue = 'Punctuality')

# %%
# Comparision of Punctuality bifurcated by Most Priced Dial  
plt.figure(figsize= (30,8))
sns.barplot(x = 'Dial', y = 'Price' , data = df ,hue = 'Punctuality')
# Out:
# <Axes: xlabel='Dial', ylabel='Price'>

# %%
#Crystal Prices 
plt.figure(figsize= (20,4))
sns.barplot(x = 'Crystal', y = 'Price', data = df)
# Out:
# <Axes: xlabel='Crystal', ylabel='Price'>

# %%
Shapewise_Sale = df.groupby(['Shape'])['Price'].sum().reset_index().sort_values(['Price'],ascending=False).head(10)
Shapewise_Sale['Price'] = Shapewise_Sale['Price']/1_000_000
Shapewise_Sale = Shapewise_Sale.rename({'Shape':'Shape','Price':'Prices in Millions'})
Shapewise_Sale
# Out:
#          Shape       Price
# 0     Circular  274.131980
# 1       Custom   79.812207
# 2  Rectangular   79.408016

# %%
plt.figure(figsize= (20,4))
sns.barplot(x = 'Shape', y = 'Price' , data = Shapewise_Sale, color = 'Red')
# Out:
# <Axes: xlabel='Shape', ylabel='Price'>

# %%
Conditionwise_Qty_sold = df.groupby(['Condition'])['Brand'].count().reset_index().sort_values(['Brand'],ascending=False)

# %%
Conditionwise_Qty_sold
# Out:
#            Condition  Brand
# 6   Used (Very good)  14646
# 1                New  12722
# 0  Like new & unworn   9084
# 3        Used (Good)   5973
# 2        Used (Fair)   1287
# 4  Used (Incomplete)     14
# 5        Used (Poor)      4

# %%
c = Numerical_data.columns.tolist()

# %%
plt.figure(figsize = (20,5))
sns.histplot(df['Condition'],kde = True , color = 'Blue')
# Out:
# <Axes: xlabel='Condition', ylabel='Count'>

# %%
sns.histplot(df['Watches Sold by the Seller'],kde = True, color = 'Red')
# Out:
# <Axes: xlabel='Watches Sold by the Seller', ylabel='Count'>

# %%
plt.figure(figsize=(16, 12))
for i in range(1, len(c) + 1):
    plt.subplot(4, 4, i)  # Create subplot with 4x4 grid
    sns.kdeplot(x=c[i-1], data=df, color='Red', fill=True, hue='Punctuality')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\JHimanshu27\AppData\Local\Temp\ipykernel_16292\1400016524.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=c[i-1], data=df, color='Red', fill=True, hue='Punctuality')
# C:\Users\JHimanshu27\AppData\Local\Temp\ipykernel_16292\1400016524.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=c[i-1], data=df, color='Red', fill=True, hue='Punctuality')
# C:\Users\JHimanshu27\AppData\Local\Temp\ipykernel_16292\1400016524.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=c[i-1], data=df, color='Red', fill=True, hue='Punctuality')
# C:\Users\JHimanshu27\AppData\Local\Temp\ipykernel_16292\1400016524.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
# ...

# %%
df
# Out:
#            Brand        Movement Case material Bracelet material  \
# 0         Roamer       Automatic         Steel             Steel
# 1         Czapek       Automatic         Steel             Steel
# 2      Montblanc          Quartz         Steel             Steel
# 3           Cyma  Manual winding         Steel             Steel
# 4         Sector       Automatic         Steel             Steel
# ...          ...             ...           ...               ...
# 43725        ZRC       Automatic         Steel             Steel
# 43726        ZRC          Quartz         Steel             Steel
# 43727        ZRC          Quartz         Steel             Steel
# 43728        ZRC       Automatic         Steel            Rubber
# 43729        ZRC       Automatic         Steel             Steel
#
#       Year of production          Condition  \
# 0                 Mystry  Like new & unworn
# 1                   2024  Like new & unworn
# 2                 Mystry                New
# ...

# %%
Genderwise_sale = df.groupby(['Gender'])['Price'].sum().sort_values(ascending=False).reset_index()

# %%
Genderwise_sale['Price']=Genderwise_sale['Price']/1_000_0000

# %%
Genderwise_sale = Genderwise_sale.rename(columns={'Gender':'Gender','Price':'Price_in_Millions'})

# %%
Genderwise_sale
# Out:
#           Gender  Price_in_Millions
# 0    Men's watch          36.247762
# 1         Unisex           4.932107
# 2  Women's watch           2.155352

# %%
df.columns
# Out:
# Index(['Brand', 'Movement', 'Case material', 'Bracelet material',
#        'Year of production', 'Condition', 'Scope of delivery', 'Gender',
#        'Price', 'Availability', 'Shape', 'Water resistance', 'Crystal', 'Dial',
#        'Bracelet color', 'Clasp', 'Watches Sold by the Seller',
#        'Active listing of the seller', 'Fast Shipper', 'Trusted Seller',
#        'Punctuality', 'Seller Reviews'],
#       dtype='object')

# %%
df['Fast Shipper'] = df['Fast Shipper'].replace({0:'No', 1:'Yes'})
df
# Out:
#            Brand        Movement Case material Bracelet material  \
# 0         Roamer       Automatic         Steel             Steel
# 1         Czapek       Automatic         Steel             Steel
# 2      Montblanc          Quartz         Steel             Steel
# 3           Cyma  Manual winding         Steel             Steel
# 4         Sector       Automatic         Steel             Steel
# ...          ...             ...           ...               ...
# 43725        ZRC       Automatic         Steel             Steel
# 43726        ZRC          Quartz         Steel             Steel
# 43727        ZRC          Quartz         Steel             Steel
# 43728        ZRC       Automatic         Steel            Rubber
# 43729        ZRC       Automatic         Steel             Steel
#
#       Year of production          Condition  \
# 0                 Mystry  Like new & unworn
# 1                   2024  Like new & unworn
# 2                 Mystry                New
# ...

# %%
df['Trusted Seller'] = df['Trusted Seller'].replace({'FALSE':'No', 'TRUE':'Yes'})
df

# %%
df['Punctuality'] = df['Punctuality'].replace({0:'No', 1:'Yes'})
df
# Out:
#            Brand        Movement Case material Bracelet material  \
# 0         Roamer       Automatic         Steel             Steel
# 1         Czapek       Automatic         Steel             Steel
# 2      Montblanc          Quartz         Steel             Steel
# 3           Cyma  Manual winding         Steel             Steel
# 4         Sector       Automatic         Steel             Steel
# ...          ...             ...           ...               ...
# 43725        ZRC       Automatic         Steel             Steel
# 43726        ZRC          Quartz         Steel             Steel
# 43727        ZRC          Quartz         Steel             Steel
# 43728        ZRC       Automatic         Steel            Rubber
# 43729        ZRC       Automatic         Steel             Steel
#
#       Year of production          Condition  \
# 0                 Mystry  Like new & unworn
# 1                   2024  Like new & unworn
# 2                 Mystry                New
# ...

# %%
Dialwise_sale =  df.groupby(['Dial'])['Price'].sum().sort_values(ascending = False).reset_index()
Dialwise_sale['Price'] = Dialwise_sale['Price']/1_000_000
Dialwise_sale = Dialwise_sale.rename(columns={'Dial':'Dial','Price':'Sale in Millions'})
Dialwise_sale
# Out:
#                Dial  Sale in Millions
# 0             White        104.733174
# 1      Skeletonized         88.198734
# 2             Black         76.082925
# 3              Blue         52.296896
# 4            Silver         35.802317
# 5              Grey         22.299676
# 6             Green         12.707251
# 7   Mother of Pearl          8.157364
# 8             Brown          6.682104
# 9              Gold          5.999922
# 10              Red          4.696302
# 11             Pink          3.637433
# 12        Champagne          3.240134
# 13           Yellow          2.084091
# 14   Silver (solid)          1.926914
# 15           Orange          1.491808
# 16           Purple          1.391076
# 17     Gold (solid)          0.920604
# 18           Bronze          0.460524
# 19         Bordeaux          0.301881
# 20        Turquoise          0.209449
# 21        Meteorite          0.031624

# %%
#len(Qty_zero_count = 
len(df[(df['Brand'] == 'Roamer') & (df['Watches Sold by the Seller'] == 0)].count())
# Out:
# 23

# %%
Sales = df[df['Brand'] == 'ZRC']['Price'].count()
Sales
# Out:
# 101

# %%
BraceletMaterialwise_sale =  df.groupby(['Bracelet material'])['Price'].sum().sort_values(ascending = False).reset_index()
BraceletMaterialwise_sale['Price'] = BraceletMaterialwise_sale['Price']/1_000_000
BraceletMaterialwise_sale = BraceletMaterialwise_sale.'Brename(columns={'Bracelet material':'Bracelet material','Price':'Sale in Millions'})
BraceletMaterialwise_sale
# Out:
#    Bracelet material  Sale in Millions
# 0             Rubber         93.934801
# 1            Leather         76.455758
# 2     Crocodile skin         71.270814
# 3              Steel         71.073207
# 4     Alligator skin         21.932373
# 5          Rose gold         21.549639
# 6            Textile         15.916710
# 7         White gold         11.509203
# 8        Yellow gold         10.482157
# 9           Titanium          8.995114
# 10          Platinum          8.585794
# 11         Calf skin          5.602118
# 12           Ceramic          4.220135
# 13           Plastic          3.456416
# 14        Gold/Steel          2.326651
# 15             Satin          1.298225
# 16           Silicon          1.236648
# 17            Carbon          0.982430
# 18       Lizard skin          0.751476
# 19          Red gold          0.387486
# 20      Ostrich skin          0.382663
# 21        Shark skin          0.284520
# 22            Silver          0.237727
# ...

# %%
Qty_Sold = df.groupby(['Watches Sold by the Seller'])['Price'].sum().sort_values(ascending = False).reset_index()
Qty_Sold['Price'] = Qty_Sold['Price']/1_000_000
Qty_Sold = Qty_Sold.rename(columns={'Qty_Sold':'Qty_Sold','Price':'Sale in Millions'})
Qty_Sold
# Out:
#       Watches Sold by the Seller  Sale in Millions
# 0                             55         43.161310
# 1                              0         29.053555
# 2                            243         12.465500
# 3                            159         10.832928
# 4                           3088          9.391935
# ...                          ...               ...
# 1399                        7223          0.000218
# 1400                         658          0.000218
# 1401                        1085          0.000217
# 1402                       10354          0.000151
# 1403                         796          0.000050
#
# [1404 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Brand', 'Movement', 'Case material', 'Bracelet material',
#        'Year of production', 'Condition', 'Scope of delivery', 'Gender',
#        'Price', 'Availability', 'Shape', 'Water resistance', 'Crystal', 'Dial',
#        'Bracelet color', 'Clasp', 'Watches Sold by the Seller',
#        'Active listing of the seller', 'Fast Shipper', 'Trusted Seller',
#        'Punctuality', 'Seller Reviews'],
#       dtype='object')

# %%
df['Revenue'] = df['Price'] * df['Watches Sold by the Seller']
df['Revenue'] = df['Revenue']/1_000_000
df = df.rename(columns={'Revenue':'Revenue in Millions'})

# %%
No_Revenue = df[df['Revenue in Millions'] == 0]
No_Revenue
# Out:
#                    Brand        Movement Case material Bracelet material  \
# 0                 Roamer       Automatic         Steel             Steel
# 3                   Cyma  Manual winding         Steel             Steel
# 4                 Sector       Automatic         Steel             Steel
# 5                 Sector       Automatic         Steel             Steel
# 6      Jaermann & StÃ¼bi       Automatic      Platinum    Crocodile skin
# ...                  ...             ...           ...               ...
# 43707             Zodiac       Automatic         Steel            Rubber
# 43708             Zodiac       Automatic         Steel             Steel
# 43709             Zodiac          Quartz         Steel           Leather
# 43715                ZRC       Automatic         Steel           Leather
# 43728                ZRC       Automatic         Steel            Rubber
#
#       Year of production          Condition  \
# 0                 Mystry  Like new & unworn
# ...

# %%
Revenue_Contributers = df[df['Revenue in Millions'] != 0]
Revenue_Contributers
# Out:
#            Brand        Movement Case material Bracelet material  \
# 1         Czapek       Automatic         Steel             Steel
# 2      Montblanc          Quartz         Steel             Steel
# 8         Czapek       Automatic         Steel            Rubber
# 10        Kobold          Quartz         Steel             Steel
# 12        Sicura  Manual winding         Steel           Leather
# ...          ...             ...           ...               ...
# 43724        ZRC       Automatic      Titanium            Rubber
# 43725        ZRC       Automatic         Steel             Steel
# 43726        ZRC          Quartz         Steel             Steel
# 43727        ZRC          Quartz         Steel             Steel
# 43729        ZRC       Automatic         Steel             Steel
#
#       Year of production          Condition  \
# 1                   2024  Like new & unworn
# 2                 Mystry                New
# 8                   2024  Like new & unworn
# ...

# %%
x = Revenue_Contributers['Movement'].value_counts().index
y = Revenue_Contributers['Movement'].value_counts().values

plt.figure(figsize = (3,3))
plt.pie(y,labels = x,autopct="%0.2f%%")

a = Revenue_Contributers['Shape'].value_counts().index
b = Revenue_Contributers['Shape'].value_counts().values

plt.figure(figsize = (3,3))
plt.pie(b,labels = a,autopct="%0.2f%%")

plt.tight_layout()

# %%
No_Revenue.columns
# Out:
# Index(['Brand', 'Movement', 'Case material', 'Bracelet material',
#        'Year of production', 'Condition', 'Scope of delivery', 'Gender',
#        'Price', 'Availability', 'Shape', 'Water resistance', 'Crystal', 'Dial',
#        'Bracelet color', 'Clasp', 'Watches Sold by the Seller',
#        'Active listing of the seller', 'Fast Shipper', 'Trusted Seller',
#        'Punctuality', 'Seller Reviews', 'Revenue in Millions'],
#       dtype='object')

# %%
sorted_scope_of_delivery1 = sorted(Revenue_Contributers['Movement'].unique())
sorted_scope_of_delivery2 = sorted(No_Revenue['Movement'].unique())
plt.figure(figsize = (13,4))
sns.barplot(x = 'Movement',y = 'Price', data = Revenue_Contributers,order=sorted_scope_of_delivery1,palette='Blues')
plt.figure(figsize = (13,4))
sns.barplot(x = 'Movement',y = 'Price', data = No_Revenue,order=sorted_scope_of_delivery2, palette='Reds')
plt.tight_layout()
# Out:
# C:\Users\JHimanshu27\AppData\Local\Temp\ipykernel_15804\3775113250.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Movement',y = 'Price', data = Revenue_Contributers,order=sorted_scope_of_delivery1,palette='Blues')
# C:\Users\JHimanshu27\AppData\Local\Temp\ipykernel_15804\3775113250.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Movement',y = 'Price', data = No_Revenue,order=sorted_scope_of_delivery2, palette='Reds')

# %%
No_Revenue['Brand'].unique().values_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[446], line 1
# ----> 1 No_Revenue['Brand'].unique().values_count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values_count'

# %%
brand_counts = No_Revenue['Brand'].value_counts()
print(brand_counts)
# Out:
# Brand
# Philip Watch        140
# Swatch              136
# Raketa              121
# Sector              117
# Timex               115
#                    ...
# AD-Chronographen      1
# Esprit                1
# FabergÃ©              1
# Chris Benz            1
# Vixa                  1
# Name: count, Length: 449, dtype: int64

# %%
brand_counts = Revenue_Contributers['Brand'].value_counts()
print(brand_counts)
# Out:
# Brand
# Patek Philippe        282
# Audemars Piguet       276
# Cartier               275
# Rolex                 274
# Richard Mille         271
#                      ...
# Milleret                1
# Rolf Lang               1
# Scalfaro                1
# Tecnotempo              1
# Yves Saint Laurent      1
# Name: count, Length: 437, dtype: int64

# %%
h = Revenue_Contributers['Brand'].unique().tolist()
h
# Out:
# ['Czapek',
#  'Montblanc',
#  'Kobold',
#  'Sicura',
#  'Charriol',
#  'Bulova',
#  'Steinhart',
#  'Michel Herbelin',
#  'Michel Jordi',
#  'Mauboussin',
#  'Ebel',
#  'Gucci',
#  'Movado',
#  'Tiffany',
#  'Swatch',
#  'Chanel',
#  'Dior',
#  'Dugena',
#  'HermÃ¨s',
#  'Lanco',
#  'Nivada',
#  'Piaget',
#  'Rotary',
#  'Wittnauer',
#  'Wyler Vetta',
#  'ZentRa',
#  'Harry Winston',
#  'Bulgari',
#  'Chaumet',
#  'Chopard',
#  'Graf',
#  'Michele',
#  'Van Cleef & Arpels',
#  'Baume & Mercier',
#  'Bertolucci',
#  'Concord',
#  'Cyma',
#  'Hamilton',
#  'Record',
#  'Louis Vuitton',
#  'Boucheron',
#  'Carl F. Bucherer',
#  'Franck Muller',
#  'Rado',
#  'Certina',
#  'Fendi',
#  'GUB GlashÃ¼tte',
#  'Parmigiani Fleurier',
#  'Raymond Weil',
#  'Bunz',
#  'Alfred Dunhill',
#  'B.R.M',
#  'BWC-Swiss',
#  'Cartier',
#  'Citizen',
#  'Favre-Leuba',
#  'Glycine',
#  'Guess',
#  'Jaeger-LeCoultre',
#  'Locman',
#  'Maurice Lacroix',
#  'Mondia',
#  'Pierre Balmain',
#  'Roamer',
# ...

# %%
p = No_Revenue['Brand'].unique().tolist()
p
# Out:
# ['Roamer',
#  'Cyma',
#  'Sector',
#  'Jaermann & StÃ¼bi',
#  'Maserati',
#  'Guess',
#  'Invicta',
#  'Dior',
#  'Baume & Mercier',
#  'Pryngeps',
#  'Wyler Vetta',
#  'Gruen',
#  'HermÃ¨s',
#  'Carl F. Bucherer',
#  'Movado',
#  'Orfina',
#  'Yves Saint Laurent',
#  'Lanco',
#  'Bulova',
#  'Charriol',
#  'Doxa',
#  'Michel Herbelin',
#  'Armani',
#  'Concord',
#  'Enicar',
#  'GÃ¼belin',
#  'Kelek',
#  'Universal GenÃ¨ve',
#  'Van Cleef & Arpels',
#  'Chaumet',
#  'Dugena',
#  'Eterna',
#  'GardÃ©',
#  'Pulsar',
#  'Tecnotempo',
#  'Alain Silberstein',
#  'Damasko',
#  'Mondaine',
#  'Rado',
#  'Raymond Weil',
#  'Skagen',
#  'Tiffany',
#  'Cerruti',
#  'Pequignet',
#  'Bifora',
#  'Ebel',
#  'Eberhard & Co.',
#  'Jacques Lemans',
#  'Lemania',
#  'Lorenz',
#  'Mondia',
#  'Atlantic',
#  'Balmain',
#  'Bertolucci',
#  'Breil',
#  'Catorex',
#  'Election',
#  'Elgin',
#  'Gucci',
#  'Juvenia',
#  'Lorus',
#  'Philip Watch',
#  'Sandoz',
#  'Sarcar',
#  'Alfred Dunhill',
# ...

# %%
df['Brand'].nunique()
# Out:
# 479

# %%
t = h.remove(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[482], line 1
# ----> 1 t = h.remove(p)
#
# ValueError: list.remove(x): x not in list

# %%
common_elements = [item for item in h if item in p]

# %%
common_elements
# Out:
# ['Czapek',
#  'Montblanc',
#  'Sicura',
#  'Charriol',
#  'Bulova',
#  'Steinhart',
#  'Michel Herbelin',
#  'Michel Jordi',
#  'Mauboussin',
#  'Ebel',
#  'Gucci',
#  'Movado',
#  'Tiffany',
#  'Swatch',
#  'Chanel',
#  'Dior',
#  'Dugena',
#  'HermÃ¨s',
#  'Lanco',
#  'Nivada',
#  'Piaget',
#  'Rotary',
#  'Wittnauer',
#  'Wyler Vetta',
#  'ZentRa',
#  'Harry Winston',
#  'Bulgari',
#  'Chaumet',
#  'Chopard',
#  'Michele',
#  'Van Cleef & Arpels',
#  'Baume & Mercier',
#  'Bertolucci',
#  'Concord',
#  'Cyma',
#  'Hamilton',
#  'Record',
#  'Louis Vuitton',
#  'Boucheron',
#  'Carl F. Bucherer',
#  'Franck Muller',
#  'Rado',
#  'Certina',
#  'Fendi',
#  'GUB GlashÃ¼tte',
#  'Parmigiani Fleurier',
#  'Raymond Weil',
#  'Alfred Dunhill',
#  'B.R.M',
#  'BWC-Swiss',
#  'Cartier',
#  'Citizen',
#  'Favre-Leuba',
#  'Glycine',
#  'Guess',
#  'Jaeger-LeCoultre',
#  'Locman',
#  'Maurice Lacroix',
#  'Mondia',
#  'Pierre Balmain',
#  'Roamer',
#  'Sector',
#  'Tissot',
# ...
